# %% [markdown]
# <a href="https://colab.research.google.com/github/arunpothencode/MyAIApplication/blob/dev20Nov24/%E0%B4%95%E0%B5%81%E0%B4%A3%E0%B5%81%E0%B4%B5%E0%B4%BE%E0%B4%B5AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nselib

# %%
import nselib
from nselib import capital_market

# %%
data = capital_market.bhav_copy_with_delivery('19-11-2024')

# %%
import pandas as pd

df = pd.DataFrame(data)

# %%
df
# Out:
#           SYMBOL SERIES        DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 0     1018GS2026     GS  19-Nov-2024      112.30      110.20      113.00
# 1      20MICRONS     BE  19-Nov-2024      223.80      219.35      223.80
# 2     21STCENMGM     BE  19-Nov-2024      107.55      105.39      105.39
# 3         360ONE     EQ  19-Nov-2024     1048.05     1051.15     1075.50
# 4      3IINFOLTD     EQ  19-Nov-2024       26.54       26.69       27.24
# ...          ...    ...          ...         ...         ...         ...
# 2737       ZTECH     ST  19-Nov-2024      377.20      390.40      396.05
# 2738       ZUARI     EQ  19-Nov-2024      215.28      216.00      221.44
# 2739    ZUARIIND     EQ  19-Nov-2024      327.50      327.90      334.95
# 2740   ZYDUSLIFE     EQ  19-Nov-2024      944.70      945.00      955.15
# 2741   ZYDUSWELL     EQ  19-Nov-2024     1918.10     1917.00     1955.00
#
#       LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  \
# ...
